# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.models.feature_extraction import get_graph_node_names
from torchvision.models.feature_extraction import create_feature_extractor


from torch.utils.data import TensorDataset, DataLoader, Dataset

import torch.nn.functional as F

import numpy as np


import matplotlib.pyplot as plt

from PIL import Image

import os
import glob


from MyDataLoader import OrderedDataSet, SiameseDataLoader, ShuffleDataLoader
from FileReader import get_picture_tensors
from MyModels import FeatureExtractionCNN
from ModelEvaluation import eval_model


from sklearn.neighbors import KNeighborsClassifier

# %%
# data params
root_directory = "dataset_chat/"
n_classes = 30
required_train_imgs = 30
required_test_imgs = 1

# %%
(train_images, val_images, test_images, 
 train_labels , val_labels , test_labels , n_classes) = get_picture_tensors(root_directory=root_directory,
                                                              n_classes=n_classes, 
                                                              required_train_imgs=required_train_imgs, 
                                                              required_test_imgs=required_test_imgs,
                                                              use_selected_eval_datasets = False, 
                                                              show_progress=False,
                                                              ordered_dataset=True)
# Out:
# 900
# 30

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on:
    """

    def __init__(self, margin=1.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, x0, x1, y):
        # euclidian distance
        diff = x0 - x1
        dist_sq = torch.sum(torch.pow(diff, 2), 1)
        dist = torch.sqrt(dist_sq)
        
        mdist = self.margin - dist
        dist = torch.clamp(mdist, min=0.0)
        loss = y * dist_sq + (1 - y) * torch.pow(dist, 2)
        loss = torch.sum(loss) / 2.0 / x0.size()[0]
        
        return loss

# %%
class SiameseDataLoader(Dataset):
    def __init__(self, ordered_dataset, batches_per_epoch):

        self.ordered_dataset = ordered_dataset
        self.batches_per_epoch = batches_per_epoch
        
    def __len__(self):
        return self.batches_per_epoch

    def __getitem__(self):
        
        same_class = np.random.choice([1, 0], 1,p=[0.9, 0.1])[0]

        if same_class:
            im1, im2 = self.ordered_dataset.get_same_class()
            
        else: 
            im1, im2 = self.ordered_dataset.get_diff_class()
        
        return im1, im2, same_class

import random

# %%
num_epochs = 30
learning_rate = 1e-5


train_ordered_dataset = OrderedDataSet(train_images)
train_dataloader = SiameseDataLoader(train_ordered_dataset, 100)

model = FeatureExtractionCNN(n_classes)

model.train()

criterion = ContrastiveLoss()
params = filter(lambda x: x.requires_grad, model.parameters())
optimizer = optim.Adam(params, lr = learning_rate)

loss_at_each_epoch = []
batches_per_epoch = 100

for epoch in range(num_epochs):
    total_loss = 0
    
    for i in range(batches_per_epoch):
        im1, im2, label = train_dataloader.__getitem__()
        optimizer.zero_grad()
        output1, output2 = model(im1, im2)

        loss = criterion(output1, output2, label)
        total_loss += loss
        loss.backward()
        optimizer.step()

    print(f"End of epoch {epoch}")
    print("Average loss in epoch: ", total_loss.item()/batches_per_epoch)
    loss_at_each_epoch.append(total_loss.item()/batches_per_epoch)
    
print('Training and evaluation finished.')
# Out:
# End of epoch 0
# Average loss in epoch:  4.073093872070313
# End of epoch 1
# Average loss in epoch:  2.1955596923828127
# End of epoch 2
# Average loss in epoch:  1.0217420959472656
# End of epoch 3
# Average loss in epoch:  0.4387088394165039
# End of epoch 4
# Average loss in epoch:  0.18636043548583983
# End of epoch 5
# Average loss in epoch:  0.11136857986450195
# End of epoch 6
# Average loss in epoch:  0.05887473583221436
# End of epoch 7
# Average loss in epoch:  0.058652920722961424
# End of epoch 8
# Average loss in epoch:  0.034630615711212155
# End of epoch 9
# Average loss in epoch:  0.04602604389190674
# End of epoch 10
# Average loss in epoch:  0.045411815643310545
# End of epoch 11
# Average loss in epoch:  0.05728391170501709
# End of epoch 12
# Average loss in epoch:  0.05740508556365967
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 25
#      23 im1, im2, label = train_dataloader.__getitem__()
#      24 optimizer.zero_grad()
# ---> 25 output1, output2 = model(im1, im2)
#      27 loss = criterion(output1, output2, label)
#      28 total_loss += loss
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Antoine\Desktop\IAA_projet\MyModels.py:86, in FeatureExtractionCNN.forward(self, input1, input2)
#      84 input2 = input2.unsqueeze(dim=0)
#      85 output1 = self.forward_once(input1)
# ---> 86 output2 = self.forward_once(input2)
#      87 return output1, output2
#
# File c:\Users\Antoine\Desktop\IAA_projet\MyModels.py:79, in FeatureExtractionCNN.forward_once(self, x)
#      78 def forward_once(self, x):
# ---> 79     output = self.model(x)
#      80     return output
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torchvision\models\resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torchvision\models\resnet.py:275, in ResNet._forward_impl(self, x)
#     273 x = self.layer1(x)
#     274 x = self.layer2(x)
# --> 275 x = self.layer3(x)
#     276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torchvision\models\resnet.py:92, in BasicBlock.forward(self, x)
#      89 def forward(self, x: Tensor) -> Tensor:
#      90     identity = x
# ---> 92     out = self.conv1(x)
#      93     out = self.bn1(out)
#      94     out = self.relu(out)
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
def flatten_innermost(lst):
    result = []
    for item in lst:
        if isinstance(item, list):
            result.extend(flatten_innermost(item))
        else:
            result.append(item)
    return result

# %%
features = []
feature_labels = []

flat_train_images = []
for class_cat in train_images:
    for im in class_cat:
        flat_train_images.append(im)

train_dataset = ShuffleDataLoader(flat_train_images, train_labels)
with torch.no_grad():
    for images, labels in train_dataset:
        images = images.unsqueeze(dim=0)
        outputs = model.forward_once(images)
        features.append(outputs[0])
        feature_labels.append(np.argmax(labels).item())

# %%
def get_nearest_neighbors_indices(knn, query_point, k):
    distances, indices = knn.kneighbors([query_point.detach().numpy()], n_neighbors=k)
    predict = knn.predict_proba([query_point.detach().numpy()])
    return predict[0]

# Create a k-NN classifier
k = 5
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(features, feature_labels)

test_dataset = ShuffleDataLoader(test_images, test_labels)
for images, labels in train_dataset:
    images = images.unsqueeze(0)
    image_array = np.transpose(images[0], (1,2,0))
    
    outputs = model.forward_once(images)
    probas = get_nearest_neighbors_indices(knn, outputs[0], k)
    print(f"Real label {torch.argmax(labels)} : -- probabilities of the classes: ")
    sorted_indices = np.argsort(probas)[::-1]
    for i in range(3):
        class_index = sorted_indices[i]
        probability = probas[class_index]
        print(f"Class {class_index}: Probability {probability}")

"""
i = 0
for images, labels in train_dataset:
    if i in hmm:
        images = images.unsqueeze(0)
        image_array = np.transpose(images[0], (1,2,0))
        plt.imshow(image_array) 
        plt.show()
    i += 1
"""
# Out:
# Real label 11 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 3: Probability 0.2
# Class 5: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 22: Probability 0.2
# Class 19: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 29: Probability 0.6
# Class 10: Probability 0.4
# Class 28: Probability 0.0
# Real label 23 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 11: Probability 0.4
# Class 0: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 21: Probability 0.4
# Class 4: Probability 0.2
# Class 22: Probability 0.2
# Real label 18 : -- probabilities of the classes:
# Class 13: Probability 0.4
# Class 2: Probability 0.2
# Class 3: Probability 0.2
# Real label 0 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 3: Probability 0.2
# Class 23: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 24: Probability 0.4
# Class 19: Probability 0.2
# Class 25: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 16: Probability 0.4
# Class 20: Probability 0.2
# Class 27: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 16: Probability 0.4
# Class 14: Probability 0.2
# Class 6: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 25: Probability 0.2
# Class 7: Probability 0.2
# Class 8: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 26: Probability 0.2
# Class 5: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 3: Probability 0.2
# Class 24: Probability 0.2
# Class 5: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 8: Probability 0.4
# Class 26: Probability 0.2
# Class 9: Probability 0.2
# Real label 0 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 16: Probability 0.2
# Class 5: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 13: Probability 0.2
# Class 27: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 2: Probability 0.4
# Class 0: Probability 0.2
# Class 26: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 12: Probability 0.2
# Class 27: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 25: Probability 0.2
# Class 21: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 13: Probability 0.4
# Class 29: Probability 0.2
# Class 11: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 13: Probability 0.2
# Class 5: Probability 0.2
# Real label 21 : -- probabilities of the classes:
# Class 12: Probability 0.2
# Class 26: Probability 0.2
# Class 8: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 25: Probability 0.4
# Class 29: Probability 0.2
# Class 19: Probability 0.2
# Real label 11 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 25: Probability 0.2
# Class 11: Probability 0.2
# Real label 0 : -- probabilities of the classes:
# Class 0: Probability 0.4
# Class 25: Probability 0.2
# Class 7: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 8: Probability 0.4
# Class 0: Probability 0.2
# Class 28: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 13: Probability 0.2
# Class 2: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 12: Probability 0.4
# Class 0: Probability 0.2
# Class 9: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 5: Probability 0.2
# Class 8: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 10: Probability 0.2
# Class 16: Probability 0.2
# Class 24: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 23: Probability 0.2
# Class 7: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 9: Probability 0.4
# Class 1: Probability 0.2
# Class 25: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 0: Probability 0.4
# Class 10: Probability 0.2
# Class 17: Probability 0.2
# Real label 0 : -- probabilities of the classes:
# Class 17: Probability 0.4
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 1: Probability 0.2
# Class 4: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 28: Probability 0.2
# Class 5: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 8: Probability 0.2
# Class 9: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 1: Probability 0.4
# Class 14: Probability 0.2
# Class 28: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 2: Probability 0.2
# Class 10: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 2: Probability 0.2
# Class 25: Probability 0.2
# Real label 21 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 5: Probability 0.2
# Class 7: Probability 0.2
# Real label 11 : -- probabilities of the classes:
# Class 21: Probability 0.4
# Class 26: Probability 0.2
# Class 16: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 4: Probability 0.2
# Class 20: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 12: Probability 0.2
# Class 25: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 25: Probability 0.2
# Class 3: Probability 0.2
# Class 4: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 20: Probability 0.2
# Class 7: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 3: Probability 0.2
# Class 5: Probability 0.2
# Class 10: Probability 0.2
# Real label 18 : -- probabilities of the classes:
# Class 21: Probability 0.2
# Class 28: Probability 0.2
# Class 17: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 25: Probability 0.2
# Class 4: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 1: Probability 0.2
# Class 9: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 22: Probability 0.2
# Class 7: Probability 0.2
# Class 8: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 25: Probability 0.2
# Class 16: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 3: Probability 0.2
# Class 5: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 1: Probability 0.2
# Class 26: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 11: Probability 0.2
# Class 28: Probability 0.2
# Class 17: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 28: Probability 0.4
# Class 12: Probability 0.2
# Class 17: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 16: Probability 0.4
# Class 21: Probability 0.2
# Class 9: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 5: Probability 0.4
# Class 27: Probability 0.2
# Class 9: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 23: Probability 0.2
# Class 7: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 3: Probability 0.2
# Class 7: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 17: Probability 0.2
# Class 6: Probability 0.2
# Real label 11 : -- probabilities of the classes:
# Class 2: Probability 0.4
# Class 25: Probability 0.2
# Class 8: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 4: Probability 0.2
# Class 18: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 27: Probability 0.6
# Class 26: Probability 0.2
# Class 7: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 23: Probability 0.2
# Class 5: Probability 0.2
# Real label 25 : -- probabilities of the classes:
# Class 11: Probability 0.4
# Class 15: Probability 0.4
# Class 10: Probability 0.2
# Real label 22 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 8: Probability 0.2
# Class 17: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 15: Probability 0.4
# Class 13: Probability 0.2
# Class 5: Probability 0.2
# Real label 18 : -- probabilities of the classes:
# Class 18: Probability 0.4
# Class 12: Probability 0.2
# Class 26: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 28: Probability 0.4
# Class 13: Probability 0.4
# Class 14: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 4: Probability 0.2
# Class 21: Probability 0.2
# Class 18: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 20: Probability 0.2
# Class 17: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 19: Probability 0.2
# Class 28: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 13: Probability 0.2
# Class 27: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 13: Probability 0.2
# Class 25: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 16: Probability 0.2
# Class 11: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 19: Probability 0.2
# Class 26: Probability 0.2
# Class 24: Probability 0.2
# Real label 11 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 3: Probability 0.2
# Class 4: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 14: Probability 0.2
# Class 9: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 1: Probability 0.2
# Class 25: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 3: Probability 0.2
# Class 4: Probability 0.2
# Class 6: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 25: Probability 0.2
# Class 24: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 3: Probability 0.4
# Class 1: Probability 0.2
# Class 8: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 3: Probability 0.2
# Class 22: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 5: Probability 0.2
# Class 21: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 21: Probability 0.2
# Class 10: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 22: Probability 0.4
# Class 0: Probability 0.2
# Class 21: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 21: Probability 0.2
# Class 26: Probability 0.2
# Class 3: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 23: Probability 0.4
# Class 19: Probability 0.2
# Class 10: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 10: Probability 0.4
# Class 17: Probability 0.2
# Class 16: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 13: Probability 0.2
# Class 26: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 13: Probability 0.2
# Class 26: Probability 0.2
# Real label 12 : -- probabilities of the classes:
# Class 12: Probability 0.2
# Class 24: Probability 0.2
# Class 23: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 26: Probability 0.2
# Class 6: Probability 0.2
# Real label 21 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 16: Probability 0.2
# Class 2: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 0: Probability 0.4
# Class 22: Probability 0.2
# Class 18: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 23: Probability 0.2
# Class 8: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 25: Probability 0.2
# Class 5: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 28: Probability 0.2
# Class 2: Probability 0.2
# Class 4: Probability 0.2
# Real label 25 : -- probabilities of the classes:
# Class 13: Probability 0.4
# Class 25: Probability 0.2
# Class 15: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 19: Probability 0.2
# Class 26: Probability 0.2
# Class 15: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 12: Probability 0.2
# Class 22: Probability 0.2
# Class 7: Probability 0.2
# Real label 12 : -- probabilities of the classes:
# Class 22: Probability 0.4
# Class 29: Probability 0.2
# Class 19: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 6: Probability 0.2
# Class 21: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 24: Probability 0.2
# Class 3: Probability 0.2
# Real label 18 : -- probabilities of the classes:
# Class 18: Probability 0.4
# Class 26: Probability 0.2
# Class 17: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 12: Probability 0.2
# Class 27: Probability 0.2
# Class 26: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 13: Probability 0.2
# Class 10: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 20: Probability 0.8
# Class 7: Probability 0.2
# Class 29: Probability 0.0
# Real label 3 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 23: Probability 0.2
# Class 16: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 3: Probability 0.4
# Class 5: Probability 0.2
# Real label 11 : -- probabilities of the classes:
# Class 12: Probability 0.4
# Class 2: Probability 0.2
# Class 11: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 8: Probability 0.2
# Class 18: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 12: Probability 0.4
# Class 26: Probability 0.2
# Class 24: Probability 0.2
# Real label 18 : -- probabilities of the classes:
# Class 13: Probability 0.4
# Class 20: Probability 0.2
# Class 25: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 5: Probability 0.2
# Class 6: Probability 0.2
# Real label 18 : -- probabilities of the classes:
# Class 12: Probability 0.2
# Class 1: Probability 0.2
# Class 21: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 15: Probability 0.4
# Class 14: Probability 0.2
# Class 23: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 10: Probability 0.4
# Class 2: Probability 0.2
# Class 20: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 5: Probability 0.4
# Class 29: Probability 0.2
# Class 7: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 5: Probability 0.2
# Class 11: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Class 6: Probability 0.2
# Real label 17 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 4: Probability 0.2
# Class 7: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 4: Probability 0.2
# Class 6: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 18: Probability 0.4
# Class 13: Probability 0.2
# Class 1: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 17: Probability 0.2
# Class 15: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 2: Probability 0.2
# Class 24: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 10: Probability 0.4
# Class 3: Probability 0.2
# Class 17: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 24: Probability 0.2
# Class 18: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 4: Probability 0.2
# Class 1: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Class 20: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 4: Probability 0.4
# Class 29: Probability 0.2
# Class 2: Probability 0.2
# Real label 21 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 25: Probability 0.2
# Class 23: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 8: Probability 0.4
# Class 2: Probability 0.2
# Class 18: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 10: Probability 0.8
# Class 14: Probability 0.2
# Class 28: Probability 0.0
# Real label 0 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 26: Probability 0.2
# Class 22: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 26: Probability 0.2
# Class 25: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 21: Probability 0.4
# Class 1: Probability 0.2
# Class 24: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 5: Probability 0.2
# Class 7: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 25: Probability 0.2
# Class 14: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 25: Probability 0.2
# Class 3: Probability 0.2
# Class 4: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 6: Probability 0.4
# Class 26: Probability 0.2
# Class 18: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 6: Probability 0.2
# Class 20: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 2: Probability 0.4
# Class 1: Probability 0.2
# Class 26: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 25: Probability 0.2
# Class 15: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 2: Probability 0.4
# Class 14: Probability 0.2
# Class 24: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 2: Probability 0.4
# Class 14: Probability 0.2
# Class 25: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 6: Probability 0.2
# Class 7: Probability 0.2
# Class 9: Probability 0.2
# Real label 17 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 2: Probability 0.2
# Class 4: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 4: Probability 0.2
# Class 17: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 23: Probability 0.2
# Class 5: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 26: Probability 0.2
# Class 25: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 8: Probability 0.2
# Class 1: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 2: Probability 0.2
# Class 4: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 16: Probability 0.4
# Class 5: Probability 0.2
# Class 19: Probability 0.2
# Real label 17 : -- probabilities of the classes:
# Class 17: Probability 0.4
# Class 23: Probability 0.2
# Class 7: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 4: Probability 0.4
# Class 0: Probability 0.2
# Class 9: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 25: Probability 0.2
# Class 5: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 26: Probability 0.2
# Class 3: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 26: Probability 0.2
# Class 20: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 25: Probability 0.2
# Class 3: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 22: Probability 0.2
# Class 6: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 23: Probability 0.4
# Class 0: Probability 0.2
# Class 6: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 24: Probability 0.2
# Class 7: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 21: Probability 0.2
# Class 6: Probability 0.2
# Class 28: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 4: Probability 0.2
# Class 5: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 28: Probability 0.4
# Class 26: Probability 0.2
# Class 25: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 11: Probability 0.2
# Class 2: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 18: Probability 0.2
# Class 12: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 25: Probability 0.2
# Class 24: Probability 0.2
# Class 4: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Class 20: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 2: Probability 0.2
# Class 23: Probability 0.2
# Real label 17 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 22: Probability 0.2
# Class 20: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 10: Probability 0.4
# Class 0: Probability 0.2
# Class 28: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 12: Probability 0.2
# Class 26: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 28: Probability 0.2
# Class 2: Probability 0.2
# Class 8: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 16: Probability 0.4
# Class 5: Probability 0.2
# Class 22: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 5: Probability 0.2
# Class 7: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 28: Probability 0.2
# Class 7: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 16: Probability 0.4
# Class 6: Probability 0.2
# Class 17: Probability 0.2
# Real label 21 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 3: Probability 0.2
# Class 19: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 10: Probability 0.4
# Class 6: Probability 0.2
# Class 18: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 3: Probability 0.2
# Class 19: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 1: Probability 0.4
# Class 5: Probability 0.2
# Class 8: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 2: Probability 0.2
# Class 25: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 3: Probability 0.2
# Class 5: Probability 0.2
# Class 18: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 19: Probability 0.4
# Class 27: Probability 0.2
# Class 22: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 25: Probability 0.2
# Class 3: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 9: Probability 0.4
# Class 29: Probability 0.2
# Class 21: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 11: Probability 0.2
# Class 28: Probability 0.2
# Class 24: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 16: Probability 0.4
# Class 0: Probability 0.2
# Class 24: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 20: Probability 0.2
# Class 9: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 25: Probability 0.2
# Class 5: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 27: Probability 0.2
# Class 7: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 12: Probability 0.2
# Class 26: Probability 0.2
# Class 21: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 5: Probability 0.4
# Class 27: Probability 0.2
# Class 2: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 15: Probability 0.2
# Class 28: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 4: Probability 0.2
# Class 6: Probability 0.2
# Class 19: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 26: Probability 0.2
# Class 24: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 0: Probability 0.4
# Class 1: Probability 0.2
# Class 19: Probability 0.2
# Real label 25 : -- probabilities of the classes:
# Class 21: Probability 0.6
# Class 26: Probability 0.2
# Class 9: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 5: Probability 0.2
# Class 6: Probability 0.2
# Real label 22 : -- probabilities of the classes:
# Class 0: Probability 0.4
# Class 23: Probability 0.2
# Class 1: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 17: Probability 0.2
# Class 4: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 25: Probability 0.2
# Class 17: Probability 0.2
# Real label 18 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 24: Probability 0.2
# Class 4: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 26: Probability 0.2
# Class 2: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 20: Probability 0.4
# Class 12: Probability 0.2
# Class 25: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 1: Probability 0.2
# Class 7: Probability 0.2
# Real label 0 : -- probabilities of the classes:
# Class 5: Probability 0.2
# Class 7: Probability 0.2
# Class 10: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 26: Probability 0.2
# Class 4: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 10: Probability 0.2
# Class 12: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 7: Probability 0.2
# Class 8: Probability 0.2
# Real label 22 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 2: Probability 0.2
# Class 4: Probability 0.2
# Real label 0 : -- probabilities of the classes:
# Class 0: Probability 0.4
# Class 9: Probability 0.2
# Class 16: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 12: Probability 0.2
# Class 24: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 7: Probability 0.4
# Class 28: Probability 0.2
# Class 11: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 6: Probability 0.2
# Class 8: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 21: Probability 0.2
# Class 28: Probability 0.2
# Class 3: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 27: Probability 0.2
# Class 20: Probability 0.2
# Real label 17 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 3: Probability 0.2
# Class 21: Probability 0.2
# Real label 17 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 2: Probability 0.2
# Class 23: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 20: Probability 0.2
# Class 28: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 24: Probability 0.2
# Class 1: Probability 0.2
# Real label 17 : -- probabilities of the classes:
# Class 18: Probability 0.4
# Class 0: Probability 0.2
# Class 13: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 13: Probability 0.2
# Class 8: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 26: Probability 0.2
# Class 4: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 26: Probability 0.2
# Class 3: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 1: Probability 0.2
# Class 19: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 6: Probability 0.2
# Class 18: Probability 0.2
# Class 10: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 12: Probability 0.4
# Class 26: Probability 0.2
# Class 7: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 10: Probability 0.2
# Class 26: Probability 0.2
# Class 24: Probability 0.2
# Real label 0 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 5: Probability 0.2
# Class 20: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 16: Probability 0.2
# Class 11: Probability 0.2
# Real label 11 : -- probabilities of the classes:
# Class 20: Probability 0.4
# Class 25: Probability 0.2
# Class 5: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 9: Probability 0.4
# Class 21: Probability 0.2
# Class 11: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 26: Probability 0.2
# Class 24: Probability 0.2
# Real label 25 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 25: Probability 0.2
# Class 23: Probability 0.2
# Real label 22 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 26: Probability 0.2
# Class 3: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 13: Probability 0.4
# Class 21: Probability 0.2
# Class 9: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 5: Probability 0.2
# Class 18: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 2: Probability 0.4
# Class 25: Probability 0.2
# Class 23: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 13: Probability 0.2
# Class 1: Probability 0.2
# Real label 10 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 1: Probability 0.2
# Class 2: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 5: Probability 0.2
# Class 7: Probability 0.2
# Class 20: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 2: Probability 0.4
# Class 27: Probability 0.2
# Class 1: Probability 0.2
# Real label 22 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 1: Probability 0.2
# Class 28: Probability 0.2
# Real label 11 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 11: Probability 0.4
# Class 2: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 25: Probability 0.2
# Class 5: Probability 0.2
# Class 18: Probability 0.2
# Real label 6 : -- probabilities of the classes:
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Class 6: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 2: Probability 0.2
# Class 23: Probability 0.2
# Real label 21 : -- probabilities of the classes:
# Class 1: Probability 0.4
# Class 4: Probability 0.2
# Class 15: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 25: Probability 0.2
# Class 3: Probability 0.2
# Class 9: Probability 0.2
# Real label 28 : -- probabilities of the classes:
# Class 16: Probability 0.2
# Class 24: Probability 0.2
# Class 23: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 1: Probability 0.2
# Class 2: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 20: Probability 0.2
# Class 8: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 5: Probability 0.2
# Class 28: Probability 0.2
# Class 26: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 24: Probability 0.2
# Class 28: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 12: Probability 0.2
# Class 26: Probability 0.2
# Class 2: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 1: Probability 0.2
# Class 26: Probability 0.2
# Real label 14 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 14: Probability 0.2
# Class 1: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 28: Probability 0.2
# Class 4: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 23: Probability 0.4
# Class 2: Probability 0.2
# Class 7: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 19: Probability 0.2
# Class 28: Probability 0.2
# Class 26: Probability 0.2
# Real label 4 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 0: Probability 0.2
# Class 10: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 3: Probability 0.2
# Class 5: Probability 0.2
# Real label 22 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 19: Probability 0.2
# Class 26: Probability 0.2
# Real label 7 : -- probabilities of the classes:
# Class 18: Probability 0.4
# Class 14: Probability 0.2
# Class 5: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 20: Probability 0.6
# Class 13: Probability 0.2
# Class 26: Probability 0.2
# Real label 8 : -- probabilities of the classes:
# Class 0: Probability 0.4
# Class 21: Probability 0.2
# Class 18: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 1: Probability 0.2
# Class 5: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 4: Probability 0.2
# Class 8: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 17: Probability 0.2
# Class 3: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 6: Probability 0.4
# Class 29: Probability 0.2
# Class 2: Probability 0.2
# Real label 22 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 1: Probability 0.2
# Class 26: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 27: Probability 0.2
# Class 3: Probability 0.2
# Class 4: Probability 0.2
# Real label 16 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 4: Probability 0.2
# Class 22: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 9: Probability 0.4
# Class 28: Probability 0.4
# Class 19: Probability 0.2
# Real label 1 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 3: Probability 0.2
# Class 21: Probability 0.2
# Real label 13 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 28: Probability 0.2
# Class 26: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 18: Probability 0.4
# Class 13: Probability 0.2
# Class 5: Probability 0.2
# Real label 11 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 26: Probability 0.2
# Class 5: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 21: Probability 0.2
# Class 19: Probability 0.2
# Class 27: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 20: Probability 0.4
# Class 5: Probability 0.2
# Class 11: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 4: Probability 0.2
# Class 5: Probability 0.2
# Real label 18 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 22: Probability 0.2
# Class 9: Probability 0.2
# Real label 9 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 13: Probability 0.2
# Class 21: Probability 0.2
# Real label 25 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 26: Probability 0.2
# Class 24: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 2: Probability 0.2
# Class 25: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 19: Probability 0.2
# Class 27: Probability 0.2
# Real label 15 : -- probabilities of the classes:
# Class 25: Probability 0.4
# Class 2: Probability 0.2
# Class 5: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 1: Probability 0.2
# Class 3: Probability 0.2
# Real label 26 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 26: Probability 0.2
# Class 3: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 24: Probability 0.4
# Class 29: Probability 0.2
# Class 26: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 27: Probability 0.2
# Class 2: Probability 0.2
# Real label 23 : -- probabilities of the classes:
# Class 26: Probability 0.4
# Class 23: Probability 0.2
# Class 6: Probability 0.2
# Real label 5 : -- probabilities of the classes:
# Class 1: Probability 0.2
# Class 2: Probability 0.2
# Class 20: Probability 0.2
# Real label 27 : -- probabilities of the classes:
# Class 26: Probability 0.2
# Class 7: Probability 0.2
# Class 8: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 25: Probability 0.4
# Class 19: Probability 0.2
# Class 10: Probability 0.2
# Real label 24 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 25: Probability 0.2
# Class 4: Probability 0.2
# Real label 19 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 6: Probability 0.2
# Class 19: Probability 0.2
# Real label 2 : -- probabilities of the classes:
# Class 24: Probability 0.4
# Class 2: Probability 0.2
# Class 4: Probability 0.2
# Real label 0 : -- probabilities of the classes:
# Class 0: Probability 0.2
# Class 5: Probability 0.2
# Class 8: Probability 0.2
# Real label 21 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 12: Probability 0.2
# Class 24: Probability 0.2
# Real label 17 : -- probabilities of the classes:
# Class 6: Probability 0.2
# Class 18: Probability 0.2
# Class 17: Probability 0.2
# Real label 3 : -- probabilities of the classes:
# Class 14: Probability 0.2
# Class 28: Probability 0.2
# Class 2: Probability 0.2
# Real label 20 : -- probabilities of the classes:
# Class 13: Probability 0.2
# Class 2: Probability 0.2
# Class 25: Probability 0.2
# Real label 21 : -- probabilities of the classes:
# Class 29: Probability 0.4
# Class 10: Probability 0.2
# Class 11: Probability 0.2
# Real label 29 : -- probabilities of the classes:
# Class 29: Probability 0.2
# Class 5: Probability 0.2
# Class 19: Probability 0.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 17
#      14 image_array = np.transpose(images[0], (1,2,0))
#      16 outputs = model.forward_once(images)
# ---> 17 probas = get_nearest_neighbors_indices(knn, outputs[0], k)
#      18 print(f"Real label {torch.argmax(labels)} : -- probabilities of the classes: ")
#      19 sorted_indices = np.argsort(probas)[::-1]
#
# Cell In[30], line 2, in get_nearest_neighbors_indices(knn, query_point, k)
#       1 def get_nearest_neighbors_indices(knn, query_point, k):
# ----> 2     distances, indices = knn.kneighbors([query_point.detach().numpy()], n_neighbors=k)
#       3     predict = knn.predict_proba([query_point.detach().numpy()])
#       4     return predict[0]
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\sklearn\neighbors\_base.py:822, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     815 use_pairwise_distances_reductions = (
#     816     self._fit_method == "brute"
#     817     and ArgKmin.is_usable_for(
#     818         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     819     )
#     820 )
#     821 if use_pairwise_distances_reductions:
# --> 822     results = ArgKmin.compute(
#     823         X=X,
#     824         Y=self._fit_X,
#     825         k=n_neighbors,
#     826         metric=self.effective_metric_,
#     827         metric_kwargs=self.effective_metric_params_,
#     828         strategy="auto",
#     829         return_distance=return_distance,
#     830     )
#     832 elif (
#     833     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     834 ):
#     835     results = _kneighbors_from_graph(
#     836         X, n_neighbors=n_neighbors, return_distance=return_distance
#     837     )
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:270, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     258     return ArgKmin64.compute(
#     259         X=X,
#     260         Y=Y,
#    (...)
#     266         return_distance=return_distance,
#     267     )
#     269 if X.dtype == Y.dtype == np.float32:
# --> 270     return ArgKmin32.compute(
#     271         X=X,
#     272         Y=Y,
#     273         k=k,
#     274         metric=metric,
#     275         chunk_size=chunk_size,
#     276         metric_kwargs=metric_kwargs,
#     277         strategy=strategy,
#     278         return_distance=return_distance,
#     279     )
#     281 raise ValueError(
#     282     "Only float64 or float32 datasets pairs are supported at this time, "
#     283     f"got: X.dtype={X.dtype} and Y.dtype={Y.dtype}."
#     284 )
#
# File sklearn\metrics\_pairwise_distances_reduction\_argkmin.pyx:575, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin32.compute()
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\sklearn\utils\fixes.py:72, in threadpool_limits(limits, user_api)
#      70     return controller.limit(limits=limits, user_api=user_api)
#      71 else:
# ---> 72     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\threadpoolctl.py:171, in threadpool_limits.__init__(self, limits, user_api)
#     167 def __init__(self, limits=None, user_api=None):
#     168     self._limits, self._user_api, self._prefixes = \
#     169         self._check_params(limits, user_api)
# --> 171     self._original_info = self._set_threadpool_limits()
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\threadpoolctl.py:268, in threadpool_limits._set_threadpool_limits(self)
#     265 if self._limits is None:
#     266     return None
# --> 268 modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                           user_api=self._user_api)
#     270 for module in modules:
#     271     # self._limits is a dict {key: num_threads} where key is either
#     272     # a prefix or a user_api. If a module matches both, the limit
#     273     # corresponding to the prefix is chosed.
#     274     if module.prefix in self._limits:
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\threadpoolctl.py:340, in _ThreadpoolInfo.__init__(self, user_api, prefixes, modules)
#     337     self.user_api = [] if user_api is None else user_api
#     339     self.modules = []
# --> 340     self._load_modules()
#     341     self._warn_if_incompatible_openmp()
#     342 else:
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\threadpoolctl.py:373, in _ThreadpoolInfo._load_modules(self)
#     371     self._find_modules_with_dyld()
#     372 elif sys.platform == "win32":
# --> 373     self._find_modules_with_enum_process_module_ex()
#     374 else:
#     375     self._find_modules_with_dl_iterate_phdr()
#
# File c:\Users\Antoine\miniconda3\envs\CatProject\lib\site-packages\threadpoolctl.py:478, in _ThreadpoolInfo._find_modules_with_enum_process_module_ex(self)
#     474 n_size = DWORD()
#     475 for h_module in h_modules:
#     476
#     477     # Get the path of the current module
# --> 478     if not ps_api.GetModuleFileNameExW(
#     479             h_process, h_module, ctypes.byref(buf),
#     480             ctypes.byref(n_size)):
#     481         raise OSError("GetModuleFileNameEx failed")
#     482     filepath = buf.value
#
# KeyboardInterrupt:
